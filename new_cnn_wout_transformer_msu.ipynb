# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %% [markdown]
# ## Transform

# %%
transform = transforms.Compose([
    transforms.RandomResizedCrop(32, scale=(0.8, 1.0)),
    transforms.ToTensor()
])

# %% [markdown]
# ## Load Dataset

# %%
# Load datasets
train_data = datasets.ImageFolder(root=r"D:\Maciel\cnnEegSchizophrenia\database\csv\train")
test_data = datasets.ImageFolder(root=r"D:\Maciel\cnnEegSchizophrenia\database\csv\test")

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
train_loader.dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2439
#     Root location: D:\Maciel\cnnEegSchizophrenia\database\csv\train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(32, 32), scale=(0.8, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=True)
#                ToTensor()
#            )

# %% [markdown]
# ## Cnn

# %%
import torch.nn as nn
import torch.nn.functional as F


class SchizophreniaCNN(nn.Module):
    def __init__(self):
        super(SchizophreniaCNN, self).__init__()
        self.conv_layer1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3)
        self.max_pool1 = nn.MaxPool2d(kernel_size=3, stride=3)
        self.conv_layer2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3)
        self.max_pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv_layer3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
        self.max_pool3 = nn.MaxPool2d(kernel_size=2, stride=2)


        self.fc1 = nn.Linear(128, 1024)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(1024, 2)  # Adjusted value
        self.relu2 = nn.ReLU()

    # Progresses data across layers    
    def forward(self, x):
        out = self.conv_layer1(x)
        out = self.max_pool1(out)
        out = self.conv_layer2(out)
        out = self.max_pool2(out)
        out = self.conv_layer3(out)
        out = self.max_pool3(out)
        
        out = out.reshape(out.size(0), -1)

        out = self.fc1(out)
        out = self.relu1(out)
        out = self.dropout1(out)
        out = self.fc2(out)
        out = self.relu2(out)

        return out

# %% [markdown]
# ## Load Params

# %%
device = torch.device("cuda")
print(device)
model = SchizophreniaCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001, weight_decay=1e-5)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2048, gamma=0.95)
# Out:
# cuda

# %%
# Initialize lists to store accuracies and labels
train_accuracies = []
test_accuracies = []
best_train_accuracy = 0
best_test_accuracy = 0


# Training loop
epochs = 5000
test_accu = 0
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    scheduler.step()
    train_accuracy = 100 * correct / total
    train_accuracies.append(train_accuracy)
    if train_accuracy > best_train_accuracy:
        best_train_accuracy = train_accuracy
    print(f"Epoch {epoch + 1}, Loss: {running_loss / len(train_loader)}, Accuracy: {train_accuracy}")

    # Evaluation loop
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_accuracy = (100 * correct) / total
    test_accuracies.append(test_accuracy)
    if test_accuracy > best_test_accuracy:
        best_test_accuracy = test_accuracy
    print(f'Acuracia das Imagens: {test_accuracy} %')
    test_accu += test_accuracy

# Plotting the accuracies
plt.figure(figsize=(10, 5))
# plt.plot(range(1, epochs + 1), train_accuracies, label='Acurácia de Treinamento')
plt.plot(range(1, epochs + 1), test_accuracies, label='Acurácia de Teste')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.title('Gráfico de Teste')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs + 1), train_accuracies, label='Acurácia de Treinamento')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.title('Gráfico de Treinamento')
plt.legend()
plt.show()
print(best_train_accuracy)
print(best_test_accuracy)
# Out:
# 97.7449774497745
# 66.88311688311688

# %%
# !pip install seaborn

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

true_labels = []
predicted_labels = []

# Evaluation loop
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())
        
cm = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Esquizofrenia'],
            yticklabels=['Normal', 'Esquizofrenia'])
plt.xlabel('Valor Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()

# %%
# Import the calculate_precision function
from sklearn.metrics import precision_score

precision = precision_score(true_labels, predicted_labels, average='weighted')
print(f'Precision: {precision}')
# Out:
# Precision: 0.6606362850779763

# %%
from sklearn.metrics import recall_score

# Call the function and print the recall
recall = recall_score(true_labels, predicted_labels, average='weighted')
print(f'Recall: {recall}')
# Out:
# Recall: 0.6385281385281385

# %%
from sklearn.metrics import f1_score

# Call the function and print the F1 score
f1 = f1_score(true_labels, predicted_labels, average='weighted')
print(f'F1 Score: {f1}')
# Out:
# F1 Score: 0.6426410625494782

# %%
import os

# Criar a pasta onde tudo será salvo (se ainda não existir)
save_folder = "./model_and_graphs/csv"
os.makedirs(save_folder, exist_ok=True)

# Caminho para salvar o modelo
model_path = os.path.join(save_folder, "schizophrenia_cnn_all.pth")
torch.save(model.state_dict(), model_path)
print(f"Modelo salvo em: {model_path}")

# Salvar o gráfico da acurácia de teste
test_graph_path = os.path.join(save_folder, "test_accuracy_graph.png")
plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs + 1), test_accuracies, label='Acurácia de Teste')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.title('Gráfico de Teste')
plt.legend()
plt.savefig(test_graph_path)
print(f"Gráfico de teste salvo em: {test_graph_path}")

# Salvar o gráfico da acurácia de treinamento
train_graph_path = os.path.join(save_folder, "train_accuracy_graph.png")
plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs + 1), train_accuracies, label='Acurácia de Treinamento')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.title('Gráfico de Treinamento')
plt.legend()
plt.savefig(train_graph_path)
print(f"Gráfico de treinamento salvo em: {train_graph_path}")

# Salvar a matriz de confusão
confusion_matrix_path = os.path.join(save_folder, "confusion_matrix.png")
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Esquizofrenia'],
            yticklabels=['Normal', 'Esquizofrenia'])
plt.xlabel('Valor Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.savefig(confusion_matrix_path)
print(f"Matriz de confusão salva em: {confusion_matrix_path}")

# Salvar as métricas no arquivo .txt
metrics_file_path = os.path.join(save_folder, "metrics.txt")
with open(metrics_file_path, "w") as f:
    f.write("Métricas do Modelo:\n")
    f.write(f"Precision: {precision:.4f}\n")
    f.write(f"Recall: {recall:.4f}\n")
    f.write(f"F1-Score: {f1:.4f}\n")
print(f"Métricas salvas em: {metrics_file_path}")
# Out:
# Modelo salvo em: ./model_and_graphs/csv\schizophrenia_cnn_all.pth
# Gráfico de teste salvo em: ./model_and_graphs/csv\test_accuracy_graph.png
# Gráfico de treinamento salvo em: ./model_and_graphs/csv\train_accuracy_graph.png
# Matriz de confusão salva em: ./model_and_graphs/csv\confusion_matrix.png
# Métricas salvas em: ./model_and_graphs/csv\metrics.txt

# %%
import torch
import torch.nn as nn
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns


# Definição do modelo SchizophreniaCNN (utilizado no treinamento)
class SchizophreniaCNN(nn.Module):
    def __init__(self):
        super(SchizophreniaCNN, self).__init__()
        self.conv_layer1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3)
        self.max_pool1 = nn.MaxPool2d(kernel_size=3, stride=3)
        self.conv_layer2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3)
        self.max_pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv_layer3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
        self.max_pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(128, 1024)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(1024, 2)  # Duas classes: Normal e Esquizofrenia
        self.relu2 = nn.ReLU()

    def forward(self, x):
        out = self.conv_layer1(x)
        out = self.max_pool1(out)
        out = self.conv_layer2(out)
        out = self.max_pool2(out)
        out = self.conv_layer3(out)
        out = self.max_pool3(out)

        out = out.view(out.size(0), -1)  # Achata a saída
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.dropout1(out)
        out = self.fc2(out)
        out = self.relu2(out)

        return out


# Caminho para o modelo salvo
MODEL_PATH = './model_and_graphs/csv/schizophrenia_cnn_all.pth'

# Caminho do dataset de teste
TEST_DATA_PATH = r'D:\Maciel\database\CrossData\edf'

# Transforms utilizados para normalização e redimensionamento
transform = transforms.Compose([
    transforms.RandomResizedCrop(32, scale=(0.8, 1.0)),
    transforms.ToTensor()
])

# Carregar o dataset de teste
test_data = datasets.ImageFolder(root=TEST_DATA_PATH)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# Classes correspondentes (definidas pela ImageFolder)
CLASS_NAMES = test_data.classes  # ['Normal', 'Schizophrenia']


# Carrega o modelo salvo
def load_model():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = SchizophreniaCNN().to(device)  # Inicializa a arquitetura
    model.load_state_dict(torch.load(MODEL_PATH, map_location=device))  # Carrega os pesos salvos
    model.eval()  # Define o modelo em modo de avaliação
    return model, device


# Avaliar o modelo e gerar matriz de confusão
def evaluate_model(model, test_loader, device):
    true_labels = []
    predicted_labels = []

    # Passar o conjunto de testes pelo modelo
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            true_labels.extend(labels.cpu().numpy())  # Converte as labels reais para numpy
            predicted_labels.extend(predicted.cpu().numpy())  # Converte os resultados preditos para numpy

    return true_labels, predicted_labels


# Função para plotar a matriz de confusão
def plot_confusion_matrix(true_labels, predicted_labels, class_names):
    cm = confusion_matrix(true_labels, predicted_labels)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Classe Predita')
    plt.ylabel('Classe Verdadeira')
    plt.title('Matriz de Confusão')
    plt.show()


# Executar a avaliação
if __name__ == "__main__":
    # Carregar o modelo treinado
    model, device = load_model()

    # Avaliar o modelo usando o conjunto de teste
    true_labels, predicted_labels = evaluate_model(model, test_loader, device)

    # Exibir relatório de classificação no terminal
    print("Relatório de Classificação:")
    print(classification_report(true_labels, predicted_labels, target_names=CLASS_NAMES, zero_division=0))

    # Gerar e exibir a matriz de confusão
    plot_confusion_matrix(true_labels, predicted_labels, CLASS_NAMES)
